# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Dataset.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.drop('Loan_ID', axis=1, inplace=True)

# %%
# Visualize outliers using boxplots for numerical columns
plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].median())

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
print('Number of people who took loan by gender')
print(df['Gender'].value_counts())
sns.countplot(x='Gender',data = df, palette='Set1')
# Out:
# Number of people who took loan by gender
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\3297389202.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender',data = df, palette='Set1')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print('Number of people who took loan by married status')
print(df['Married'].value_counts())
sns.countplot(x='Married',data = df, palette='Set1')
# Out:
# Number of people who took loan by married status
# Married
# Yes    401
# No     213
# Name: count, dtype: int64
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\2929146379.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Married',data = df, palette='Set1')
# <Axes: xlabel='Married', ylabel='count'>

# %%
print('Number of people who took loan by education status')
print(df['Education'].value_counts())
sns.countplot(x='Education',data = df, palette='Set1')
# Out:
# Number of people who took loan by education status
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\492778252.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Education',data = df, palette='Set1')
# <Axes: xlabel='Education', ylabel='count'>

# %%
print('Number of people who took loan by self employed status')
print(df['Self_Employed'].value_counts())
sns.countplot(x='Self_Employed',data = df, palette='Set1')
# Out:
# Number of people who took loan by self employed status
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\1125429378.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Self_Employed',data = df, palette='Set1')
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Income
# 0         Urban           Y        5849.0
# ...

# %%
df['ApplicantIncomelog'] = np.log(df['ApplicantIncome'] + 1)
sns.distplot(df['ApplicantIncomelog'])
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\4014646754.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncomelog'])
# <Axes: xlabel='ApplicantIncomelog', ylabel='Density'>

# %%
df['LoanAmountlog'] = np.log(df['LoanAmount'] + 1)
sns.distplot(df['LoanAmountlog'])
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\1177838966.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmountlog'])
# <Axes: xlabel='LoanAmountlog', ylabel='Density'>

# %%
df['Loan_Amount_Term_log'] = np.log(df['Loan_Amount_Term'] + 1)
sns.distplot(df['Loan_Amount_Term_log'])
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\1844149724.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term_log'])
# <Axes: xlabel='Loan_Amount_Term_log', ylabel='Density'>

# %%
df['Total_Income_log'] = np.log(df['Total_Income'] + 1)
sns.distplot(df['Total_Income_log'])
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_21168\600668823.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_Income_log'])
# <Axes: xlabel='Total_Income_log', ylabel='Density'>

# %%
cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income']
df = df.drop(columns = cols, axis = 1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomelog  LoanAmountlog  \
# 0         Urban           Y            8.674197       4.859812
# 1         Rural           N            8.430327       4.859812
# 2         Urban           Y            8.006701       4.204693
# 3         Urban           Y            7.857094       4.795791
# 4         Urban           Y            8.699681       4.955827
#
#    Loan_Amount_Term_log  Total_Income_log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender','Married','Education','Dependents','Self_Employed','Property_Area','Loan_Status']
le =  LabelEncoder()
for col in cols:
  df[col] =  le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomelog  LoanAmountlog  \
# 0              2            1            8.674197       4.859812
# 1              0            0            8.430327       4.859812
# 2              2            1            8.006701       4.204693
# 3              2            1            7.857094       4.795791
# 4              2            1            8.699681       4.955827
#
#    Loan_Amount_Term_log  Total_Income_log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %%
df.dtypes
# Out:
# Gender                    int64
# Married                   int64
# Dependents                int64
# Education                 int64
# Self_Employed             int64
# Credit_History          float64
# Property_Area             int64
# Loan_Status               int64
# ApplicantIncomelog      float64
# LoanAmountlog           float64
# Loan_Amount_Term_log    float64
# Total_Income_log        float64
# dtype: object

# %%
X = df.drop(columns = ['Loan_Status'],axis = 1)
y = df['Loan_Status']

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25,random_state = 42)

# %%
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = log_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Logistic Regression Accuracy:", accuracy)
print("Logistic Regression Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Cross Validation score of Logistic Regresion: ", cross_val_score(log_model, X_train, y_train, cv=5).mean())
# Out:
# Logistic Regression Accuracy: 0.7727272727272727
# Logistic Regression Confusion Matrix:
#  [[21 33]
#  [ 2 98]]
# Cross Validation score of Logistic Regresion:  0.8217391304347826

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = tree_model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_tree)

# %%
print("Accuracy score of Decision Tree: ", accuracy)
print("Confusion Matrix of Decision Tree: \n", confusion_matrix(y_test, y_pred_tree))
print("Cross Validation score of Decision Tree: ", cross_val_score(tree_model, X, y, cv=5).mean())
# Out:
# Accuracy score of Decision Tree:  0.7142857142857143
# Confusion Matrix of Decision Tree:
#  [[27 27]
#  [17 83]]
# Cross Validation score of Decision Tree:  0.70687724910036

# %%
forest_model = RandomForestClassifier()
forest_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_forest = forest_model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_forest)

# %%
print("Accuracy score of Random Forest: ", accuracy)
print("Confusion Matrix of Random Forest: \n", confusion_matrix(y_test, y_pred_forest))
print("Cross Validation score of Random Forest: ", cross_val_score(forest_model, X, y, cv=5).mean())
# Out:
# Accuracy score of Random Forest:  0.7792207792207793
# Confusion Matrix of Random Forest:
#  [[24 30]
#  [ 4 96]]
# Cross Validation score of Random Forest:  0.7866853258696522

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_knn)

# %%
print("Accuracy score of KNeighbors: ", accuracy)
print("Confusion Matrix of KNeighbors: \n", confusion_matrix(y_test, y_pred_forest))
print("Cross Validation score of KNeighbors: ", cross_val_score(forest_model, X, y, cv=5).mean())
# Out:
# Accuracy score of KNeighbors:  0.7337662337662337
# Confusion Matrix of KNeighbors:
#  [[24 30]
#  [ 4 96]]
# Cross Validation score of KNeighbors:  0.7785419165667067

# %%
from sklearn.metrics import classification_report

def generate_classification_report(model_name,y_test,y_pred):
  report = classification_report(y_test,y_pred)
  print(f"Classification Report For {model_name}:\n{report}\n")

generate_classification_report(log_model,y_test,y_pred)
generate_classification_report(tree_model,y_test,y_pred_tree)
generate_classification_report(forest_model,y_test,y_pred_forest)
generate_classification_report(knn_model,y_test,y_pred_knn)
# Out:
# Classification Report For LogisticRegression(max_iter=1000):
#               precision    recall  f1-score   support
#
#            0       0.91      0.39      0.55        54
#            1       0.75      0.98      0.85       100
#
#     accuracy                           0.77       154
#    macro avg       0.83      0.68      0.70       154
# weighted avg       0.81      0.77      0.74       154
#
#
# Classification Report For DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.61      0.50      0.55        54
#            1       0.75      0.83      0.79       100
#
#     accuracy                           0.71       154
#    macro avg       0.68      0.67      0.67       154
# weighted avg       0.71      0.71      0.71       154
#
#
# Classification Report For RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.86      0.44      0.59        54
# ...

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
oversample = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversample.fit_resample(X,y)

df_resampled = pd.concat([pd.DataFrame(X_resampled,columns=X.columns),pd.Series(y_resampled,name="Loan_status")],axis=1)

# %%
X_resampled
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 839       1        1           3          1              0             1.0
# 840       1        1           1          0              0             1.0
# 841       1        1           1          0              0             0.0
# 842       1        1           2          1              0             0.0
# 843       1        0           0          0              0             0.0
#
# ...

# %%
y_resampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 839    0
# 840    0
# 841    0
# 842    0
# 843    0
# Name: Loan_Status, Length: 844, dtype: int64

# %%
y_resampled.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    422
# Name: count, dtype: int64

# %%
X_resampled_train, X_resampled_test, y_resampled_train, y_resampled_test = train_test_split(X_resampled,y_resampled,test_size = 0.25,random_state=42)

# %%
## Logistic Regression
log_model = LogisticRegression()
log_model.fit(X_resampled_train,y_resampled_train)
y_pred = log_model.predict(X_resampled_test)
accuracy = accuracy_score(y_resampled_test,y_pred)
accuracy*100
# Out:
# c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 68.24644549763033

# %%
## Decision Tree Classifier

tree_model = DecisionTreeClassifier()
tree_model.fit(X_resampled_train,y_resampled_train)
y_pred_tree = tree_model.predict(X_resampled_test)
accuracy = accuracy_score(y_resampled_test,y_pred_tree)
print("Accuracy score of Decision Tree: ", accuracy*100)
# Out:
# Accuracy score of Decision Tree:  78.19905213270142

# %%
## Random Forest Classifier
forest_model = RandomForestClassifier()
forest_model.fit(X_resampled_train,y_resampled_train)
y_pred_forest = forest_model.predict(X_resampled_test)
accuracy = accuracy_score(y_resampled_test,y_pred_forest)
print("Accuracy score of Random Forest: ", accuracy*100)
# Out:
# Accuracy score of Random Forest:  88.15165876777252

# %%
#KNearestNeighbors model
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_resampled_train,y_resampled_train)
y_pred_knn = knn_model.predict(X_resampled_test)
accuracy = accuracy_score(y_resampled_test,y_pred_knn)
print("Accuracy score of KNeighbors: ", accuracy*100)
# Out:
# Accuracy score of KNeighbors:  72.03791469194313

# %%
from sklearn.metrics import classification_report

def generate_classification_report(model_name,y_test,y_pred):
  report = classification_report(y_test,y_pred)
  print(f"Classification Report For {model_name}:\n{report}\n")

generate_classification_report(log_model,y_resampled_test,y_pred)
generate_classification_report(tree_model,y_resampled_test,y_pred_tree)
generate_classification_report(forest_model,y_resampled_test,y_pred_forest)
generate_classification_report(knn_model,y_resampled_test,y_pred_knn)
# Out:
# Classification Report For LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.82      0.53      0.64       114
#            1       0.61      0.87      0.71        97
#
#     accuracy                           0.68       211
#    macro avg       0.72      0.70      0.68       211
# weighted avg       0.72      0.68      0.68       211
#
#
# Classification Report For DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       114
#            1       0.81      0.69      0.74        97
#
#     accuracy                           0.78       211
#    macro avg       0.79      0.78      0.78       211
# weighted avg       0.78      0.78      0.78       211
#
#
# Classification Report For RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89       114
# ...

# %%
import pickle
with open('random_forest_model.pkl', 'wb') as file:
    pickle.dump(forest_model, file)
print("Model trained and saved as random_forest_model.pkl")
# Out:
# Model trained and saved as random_forest_model.pkl
